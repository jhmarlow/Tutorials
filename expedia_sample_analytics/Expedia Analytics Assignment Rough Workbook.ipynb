# %% [markdown]
# # Expedia Analytics Assignment

# %% [markdown]
# ### Definitions
#
# **Week**
# The year and week that the booking took place. 2016-W45 is the week beginning 07/11/2016
#
# **Platform**
# Type of device used to make the booking - Desktop computer, Mobile App (on a Smartphone or Tablet device), or our Mobile website (on a Smartphone or Tablet device)
#
# **Super Region**
# The region that the traveler originates from (North America, Asia-Pacific, Europe Middle East & Africa or Latin America)
#
# **Country Name**
# The country that the traveler originates from
#
# **Booking Window Group**
# Refers to the number of days between the customer booking and checking into the hotel. E.g. if a customer booked a trip on January 1st and checked in on January 10th, the booking window would be 9 days
#
# **Property Country**
# The country in which the booked hotel is located
#
# **Net Gross Booking Value USD**
# The total $ amount that customers pay to Hotels.com for their hotel reservation. The value of cancelled bookings is removed
#
# **Net Orders**
# The total number of hotel bookings made - the number of bookings cancelled

# %% [markdown]
# ### IDEAS
#
# Group by month to see increased usage of mobile app?
# more cancellations on mobile app because brief usage
# wheres most profitable

# %%
#import modules
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
# Load dataset from xlsx file, 'Data' sheet only
dataset = pd.read_excel (r'/Users/jacobmarlow/Desktop/Assignment_Analytics_Graduate.xlsx',
                    sheet_name='Data') 

# Take a look
dataset.head()
# Out:
#        Week Mobile Indicator Name Platform Type Name Super Region  \
# 0  2016-W45               Desktop            Desktop         APAC
# 1  2016-W45               Desktop            Desktop         APAC
# 2  2016-W45               Desktop            Desktop         APAC
# 3  2016-W45               Desktop            Desktop         APAC
# 4  2016-W45               Desktop            Desktop         APAC
#
#   Country Name Booking Window Group Property Country  \
# 0  South Korea            8-14 days          Algeria
# 1  South Korea             +90 days          Andorra
# 2  South Korea           46-60 days          Andorra
# 3    Australia           31-45 days        Argentina
# 4    Australia           15-30 days        Argentina
#
#    Net Gross Booking Value USD  Net Orders
# 0                    -608.4244          -3
# 1                    -512.1796          -2
# 2                     103.4298           1
# 3                     395.9592           1
# 4                     373.4194           1

# %%
dataset[dataset['Property Country']=='Algeria']
# Out:
#            Week Mobile Indicator Name Platform Type Name Super Region  \
# 0      2016-W45               Desktop            Desktop         APAC
# 1316   2016-W45               Desktop            Desktop         EMEA
# 1317   2016-W45               Desktop            Desktop         EMEA
# 1318   2016-W45               Desktop            Desktop         EMEA
# 3085   2016-W45               Desktop            Desktop          NaN
# 4181   2016-W45                Mobile         Mobile App         APAC
# 9730   2016-W46               Desktop            Desktop         EMEA
# 9731   2016-W46               Desktop            Desktop         EMEA
# 9732   2016-W46               Desktop            Desktop         EMEA
# 9733   2016-W46               Desktop            Desktop         EMEA
# 9734   2016-W46               Desktop            Desktop         EMEA
# 11122  2016-W46               Desktop            Desktop        LATAM
# 12631  2016-W46                Mobile         Mobile App         APAC
# 14008  2016-W46                Mobile         Mobile App          NaN
# 18263  2016-W47               Desktop            Desktop         EMEA
# 18264  2016-W47               Desktop            Desktop         EMEA
# 18265  2016-W47               Desktop            Desktop         EMEA
# 18266  2016-W47               Desktop            Desktop         EMEA
# 19604  2016-W47               Desktop            Desktop        LATAM
# 19978  2016-W47               Desktop            Desktop          NaN
# 19979  2016-W47               Desktop            Desktop          NaN
# 19980  2016-W47               Desktop            Desktop          NaN
# 19981  2016-W47               Desktop            Desktop          NaN
# 19982  2016-W47               Desktop            Desktop          NaN
# 22460  2016-W47                Mobile         Mobile App          NaN
# 23735  2016-W47                Mobile         Mobile Web         EMEA
# 23736  2016-W47                Mobile         Mobile Web         EMEA
# 24660  2016-W47                Mobile         Mobile Web          NaN
# 25309  2016-W48               Desktop            Desktop         APAC
# 26632  2016-W48               Desktop            Desktop         EMEA
# ...         ...                   ...                ...          ...
# 43849  2017-W46               Desktop            Desktop         APAC
# 45305  2017-W46               Desktop            Desktop         EMEA
# 45306  2017-W46               Desktop            Desktop         EMEA
# 45307  2017-W46               Desktop            Desktop         EMEA
# 45308  2017-W46               Desktop            Desktop         EMEA
# 47255  2017-W46               Desktop            Desktop          NaN
# 47256  2017-W46               Desktop            Desktop          NaN
# 47257  2017-W46               Desktop            Desktop          NaN
# 50228  2017-W46                Mobile         Mobile App        LATAM
# 52061  2017-W46                Mobile         Mobile Web         EMEA
# 54000  2017-W47               Desktop            Desktop         APAC
# 55405  2017-W47               Desktop            Desktop         EMEA
# 55406  2017-W47               Desktop            Desktop         EMEA
# 55407  2017-W47               Desktop            Desktop         EMEA
# 55408  2017-W47               Desktop            Desktop         EMEA
# 55409  2017-W47               Desktop            Desktop         EMEA
# 55410  2017-W47               Desktop            Desktop         EMEA
# 55411  2017-W47               Desktop            Desktop         EMEA
# 55412  2017-W47               Desktop            Desktop         EMEA
# 55413  2017-W47               Desktop            Desktop         EMEA
# 57327  2017-W47               Desktop            Desktop          NaN
# 57328  2017-W47               Desktop            Desktop          NaN
# 57329  2017-W47               Desktop            Desktop          NaN
# 59505  2017-W47                Mobile         Mobile App         EMEA
# 61930  2017-W47                Mobile         Mobile Web         EMEA
# 63769  2017-W48               Desktop            Desktop         APAC
# 65206  2017-W48               Desktop            Desktop         EMEA
# 67162  2017-W48               Desktop            Desktop          NaN
# 67163  2017-W48               Desktop            Desktop          NaN
# 67164  2017-W48               Desktop            Desktop          NaN
#
#          Country Name Booking Window Group Property Country  \
# 0         South Korea            8-14 days          Algeria
# 1316   United Kingdom             2-3 days          Algeria
# 1317   United Kingdom            8-14 days          Algeria
# 1318   United Kingdom           31-45 days          Algeria
# 3085               US           31-45 days          Algeria
# 4181      South Korea             4-7 days          Algeria
# 9730   United Kingdom           15-30 days          Algeria
# 9731   United Kingdom             4-7 days          Algeria
# 9732   United Kingdom             0-1 days          Algeria
# 9733   United Kingdom             2-3 days          Algeria
# 9734   United Kingdom            8-14 days          Algeria
# 11122          Brazil           46-60 days          Algeria
# 12631     South Korea             4-7 days          Algeria
# 14008              US            8-14 days          Algeria
# 18263  United Kingdom           15-30 days          Algeria
# 18264  United Kingdom           31-45 days          Algeria
# 18265  United Kingdom             2-3 days          Algeria
# 18266  United Kingdom             4-7 days          Algeria
# 19604          Brazil           46-60 days          Algeria
# 19978              US           31-45 days          Algeria
# 19979              US             4-7 days          Algeria
# 19980              US             +90 days          Algeria
# 19981              US           15-30 days          Algeria
# 19982              US             2-3 days          Algeria
# 22460              US             4-7 days          Algeria
# 23735  United Kingdom            8-14 days          Algeria
# 23736  United Kingdom             +90 days          Algeria
# 24660              US           15-30 days          Algeria
# 25309     South Korea             2-3 days          Algeria
# 26632  United Kingdom            8-14 days          Algeria
# ...               ...                  ...              ...
# 43849     South Korea           15-30 days          Algeria
# 45305  United Kingdom             2-3 days          Algeria
# 45306  United Kingdom           15-30 days          Algeria
# 45307  United Kingdom            8-14 days          Algeria
# 45308  United Kingdom             4-7 days          Algeria
# 47255              US           31-45 days          Algeria
# 47256              US             0-1 days          Algeria
# 47257              US           15-30 days          Algeria
# 50228          Brazil           15-30 days          Algeria
# 52061  United Kingdom             0-1 days          Algeria
# 54000       Australia             2-3 days          Algeria
# 55405          Norway             4-7 days          Algeria
# 55406          Norway             2-3 days          Algeria
# 55407          Norway           15-30 days          Algeria
# 55408  United Kingdom             4-7 days          Algeria
# 55409  United Kingdom             0-1 days          Algeria
# 55410  United Kingdom           31-45 days          Algeria
# 55411  United Kingdom           15-30 days          Algeria
# 55412  United Kingdom            8-14 days          Algeria
# 55413  United Kingdom             +90 days          Algeria
# 57327              US             4-7 days          Algeria
# 57328              US             2-3 days          Algeria
# 57329              US           46-60 days          Algeria
# 59505          Norway             4-7 days          Algeria
# 61930  United Kingdom             0-1 days          Algeria
# 63769     South Korea           31-45 days          Algeria
# 65206  United Kingdom             2-3 days          Algeria
# 67162              US           31-45 days          Algeria
# 67163              US             4-7 days          Algeria
# 67164              US            8-14 days          Algeria
#
#        Net Gross Booking Value USD  Net Orders
# 0                        -608.4244          -3
# 1316                     1064.5164           1
# 1317                      150.1357           1
# 1318                      847.2309           1
# 3085                      466.9200           1
# 4181                     3639.7452           2
# 9730                    -2435.0166          -1
# 9731                      408.5040           1
# 9732                    -3739.9995          -1
# 9733                      107.2692           1
# 9734                      490.9090           2
# 11122                     635.0244           1
# 12631                   -1813.8464          -1
# 14008                     655.7187           1
# 18263                     988.8876           1
# 18264                     473.0568           1
# 18265                       0.0000           0
# 18266                     812.1300           1
# 19604                    -635.0244          -1
# 19978                       0.0000           0
# 19979                     690.8400           1
# 19980                    2982.8288           1
# 19981                     731.9622           1
# 19982                    2980.9800           3
# 22460                    1667.7100           3
# 23735                     -63.9267           0
# 23736                     375.4806           1
# 24660                    1459.6800           1
# 25309                     223.8972           1
# 26632                    1011.7542           4
# ...                            ...         ...
# 43849                     137.0150           1
# 45305                    1883.0656           2
# 45306                     680.5417           2
# 45307                   -1235.3187           1
# 45308                     888.0548           1
# 47255                       0.0000           0
# 47256                       0.0000           0
# 47257                    3145.5488           2
# 50228                    -323.8218          -1
# 52061                    -267.1628           0
# 54000                      59.9035           1
# 55405                    1653.9743           2
# 55406                     721.9230           1
# 55407                     213.3972           1
# 55408                     904.9548           2
# 55409                     621.0324           1
# 55410                    1682.6907           1
# 55411                     318.5610           0
# 55412                     110.1661           1
# 55413                      92.8363           1
# 57327                     573.9400           1
# 57328                     771.5400           1
# 57329                    -807.0400          -1
# 59505                     866.1904           1
# 61930                     797.3162           0
# 63769                     134.4834           1
# 65206                      68.8571           1
# 67162                       0.0000           0
# 67163                    1202.8500           1
# 67164                      41.0000           1
#
# [87 rows x 9 columns]

# %%
# What signals/data available
list(dataset)
# Out:
# ['Week',
#  'Mobile Indicator Name',
#  'Platform Type Name',
#  'Super Region',
#  'Country Name',
#  'Booking Window Group',
#  'Property Country',
#  'Net Gross Booking Value USD',
#  'Net Orders']

# %%
dataset.describe(percentiles=None, include=None, exclude=None)
# Out:
#        Net Gross Booking Value USD    Net Orders
# count                 7.368800e+04  73688.000000
# mean                  1.274363e+04     47.954606
# std                   2.072294e+05    991.128900
# min                  -9.689693e+04    -50.000000
# 25%                   2.158794e+02      1.000000
# 50%                   8.575607e+02      2.000000
# 75%                   3.198414e+03      8.000000
# max                   1.166149e+07  63230.000000

# %%
platform_split = dataset.groupby('Mobile Indicator Name').size()

# %%
platform_split.values.sum()
# Out:
# 73688

# %%
# Total Net Gross Booking Value
dataset['Net Gross Booking Value USD'].sum()
# Out:
# 939052525.9852998

# %%
# by platform
dataset.groupby('Mobile Indicator Name')['Net Gross Booking Value USD'].sum()
# Out:
# Mobile Indicator Name
# Desktop    6.693461e+08
# Mobile     2.697064e+08
# Name: Net Gross Booking Value USD, dtype: float64

# %%
plt.bar(platform_split.index.values, platform_split.values, width=0.8)
# Out:
# <BarContainer object of 2 artists>

# %%
# Type of device used to make the booking - Desktop computer, 
# Mobile App (on a Smartphone or Tablet device), or our Mobile website 
# (on a Smartphone or Tablet device)
Platform_Type_Name_Count = dataset.groupby('Platform Type Name').size()
print(Platform_Type_Name_Count)
# Out:
# Platform Type Name
# Desktop       35048
# Mobile App    18788
# Mobile Web    19852
# dtype: int64

# %%
Platform_Type_Name_Count.values.sum()
# Out:
# 73688

# %%
# The region that the traveler originates from 
# (North America, Asia-Pacific, Europe Middle East & Africa or Latin America)
# APAC = Asia-Pacific
# EMEA = Europe
# LATAM = Latin America

Super_Region_Count = dataset.groupby('Super Region').size()
print(Super_Region_Count)
Super_Region_Count.values.sum()
# Out:
# Super Region
# APAC     23805
# EMEA     23477
# LATAM     6141
# dtype: int64
# 53423

# %%
# See miscount after review (total lines = 73688)
# After reviewing data NA picked up as NA
dataset['Super Region'] = dataset['Super Region'].replace(to_replace=float('nan'), value='NA', method='pad')

# %%
# Try again 
Super_Region_Count = dataset.groupby('Super Region').size()
print(Super_Region_Count)
Super_Region_Count.values.sum()
# Out:
# Super Region
# APAC     23805
# EMEA     23477
# LATAM     6141
# NA       20265
# dtype: int64
# 73688

# %%
# The country that the traveler originates from
Country_Name_Count = dataset.groupby('Country Name').size()

plt.bar(Country_Name_Count.index.values, Country_Name_Count.values)
# Out:
# <BarContainer object of 7 artists>

# %%
# Refers to the number of days between the customer booking and checking 
# into the hotel. E.g. if a customer booked a trip on January 1st and 
# checked in on January 10th, the booking window would be 9 days
dataset.groupby('Booking Window Group').size()
# Out:
# Booking Window Group
# +90 days      8529
# 0-1 days      9331
# 15-30 days    9080
# 2-3 days      8018
# 31-45 days    8084
# 4-7 days      8175
# 46-60 days    7131
# 61-90 days    7057
# 8-14 days     8243
# Post Book       40
# dtype: int64

# %%
# The country in which the booked hotel is located
Property_Country_Count = dataset.groupby('Property Country').size()
print(Property_Country_Count)
# Out:
# Property Country
# Albania                               55
# Algeria                               87
# American Samoa                        15
# Andorra                               97
# Angola                                31
# Anguilla                              42
# Antigua and Barbuda                  188
# Argentina                            807
# Armenia                               48
# Aruba                                271
# Australia                           1332
# Austria                             1026
# Azerbaijan                            88
# Bahamas                              310
# Bahrain                              218
# Bangladesh                           121
# Barbados                             292
# Belarus                               37
# Belgium                              976
# Belize                               200
# Benin                                 15
# Bermuda                              118
# Bhutan                                 2
# Bolivia                              291
# Bonaire, Sint Eustatius and Saba      50
# Bosnia and Herzegovina                80
# Botswana                              57
# Brazil                               945
# British Virgin Islands               132
# Brunei                                80
#                                     ...
# St. Vincent and the Grenadines        55
# State of Palestine                     4
# Suriname                              40
# Svalbard                              53
# Swaziland                             24
# Sweden                               888
# Switzerland                         1067
# Taiwan, Republic of China            955
# Tajikistan                             2
# Tanzania                             310
# Thailand                            1439
# Togo                                  10
# Tonga                                 10
# Trinidad and Tobago                  244
# Tunisia                              202
# Turkey                               927
# Turks and Caicos                     178
# U.S. Virgin Islands                  239
# Uganda                               111
# Ukraine                              344
# United Arab Emirates                1074
# United Kingdom                      1430
# United States of America            1530
# Uruguay                              438
# Uzbekistan                            39
# Vanuatu                               82
# Venezuela                            108
# Vietnam                             1180
# Zambia                               139
# Zimbabwe                             185
# Length: 206, dtype: int64

# %%
Property_Country_Count.values.sum()
# Out:
# 73688

# %%
# The total $ amount that customers pay to Hotels.com for their hotel 
# reservation. The value of cancelled bookings is removed
dataset.groupby('Net Gross Booking Value USD').size()
# Out:
# Net Gross Booking Value USD
# -9.689693e+04    1
# -6.678927e+04    1
# -6.160039e+04    1
# -6.054669e+04    1
# -4.905519e+04    1
# -3.754777e+04    1
# -3.669678e+04    1
# -3.254291e+04    1
# -3.240011e+04    1
# -3.236872e+04    1
# -3.110241e+04    1
# -2.889829e+04    1
# -2.795755e+04    1
# -2.704896e+04    1
# -2.551476e+04    1
# -2.521676e+04    1
# -2.297342e+04    1
# -2.290353e+04    1
# -2.170750e+04    1
# -2.152493e+04    1
# -2.093247e+04    1
# -2.071174e+04    1
# -1.934455e+04    1
# -1.930686e+04    1
# -1.907291e+04    1
# -1.839021e+04    1
# -1.826566e+04    1
# -1.818183e+04    1
# -1.809648e+04    1
# -1.745820e+04    1
#                 ..
#  6.533993e+06    1
#  6.534758e+06    1
#  6.577019e+06    1
#  6.638984e+06    1
#  6.695938e+06    1
#  6.723520e+06    1
#  6.796831e+06    1
#  6.962586e+06    1
#  6.976607e+06    1
#  7.110764e+06    1
#  7.226565e+06    1
#  7.282330e+06    1
#  7.391648e+06    1
#  7.670863e+06    1
#  7.771650e+06    1
#  7.955933e+06    1
#  7.995718e+06    1
#  8.031105e+06    1
#  8.332554e+06    1
#  8.454608e+06    1
#  8.486071e+06    1
#  8.576771e+06    1
#  8.871969e+06    1
#  9.048794e+06    1
#  9.648802e+06    1
#  1.061068e+07    1
#  1.115163e+07    1
#  1.115722e+07    1
#  1.159978e+07    1
#  1.166149e+07    1
# Length: 71587, dtype: int64

# %%
# The total number of hotel bookings made - the number of bookings cancelled
dataset.groupby('Net Orders').size()
# Out:
# Net Orders
# -50           1
# -31           1
# -25           1
# -21           1
# -18           1
# -17           2
# -15           1
# -14           2
# -13           3
# -12           4
# -11           5
# -10           8
# -8            7
# -7           17
# -6           17
# -5           31
# -4           65
# -3          149
# -2          495
# -1         2594
#  0         4073
#  1        20251
#  2         9401
#  3         5794
#  4         4057
#  5         2945
#  6         2233
#  7         1825
#  8         1538
#  9         1272
#           ...
#  28036        1
#  28345        1
#  28400        1
#  29233        1
#  29534        1
#  29963        1
#  30293        1
#  30554        1
#  30940        1
#  30968        1
#  31244        1
#  31914        1
#  32182        1
#  32906        1
#  33555        1
#  33790        1
#  34649        1
#  35077        1
#  44489        1
#  46160        1
#  46730        1
#  50949        1
#  51428        1
#  51611        1
#  57201        1
#  59226        1
#  61181        1
#  61232        1
#  62494        1
#  63230        1
# Length: 855, dtype: int64

# %%
import datetime
d = "2016-W45"
r = datetime.datetime.strptime(d + '-D1', "%Y-W%W-D%w")
print(r)
# Out:
# 2016-11-07 00:00:00

# %%
dataset['Week'][1]
# Out:
# '2016-W45'

# %%
week_list = []
year_list = []
for row, info in dataset.iterrows():
    datetime_element = datetime.datetime.strptime(dataset['Week'][row] + '-D1', "%Y-W%W-D%w")
    week_list.append(datetime_element.strftime("%V"))
    year_list.append(datetime_element.strftime("%Y"))

# %%
dataset['Week No'] = week_list
dataset['Year'] = year_list

# %%
dataset.head()
# Out:
#        Week Mobile Indicator Name Platform Type Name Super Region  \
# 0  2016-W45               Desktop            Desktop         APAC
# 1  2016-W45               Desktop            Desktop         APAC
# 2  2016-W45               Desktop            Desktop         APAC
# 3  2016-W45               Desktop            Desktop         APAC
# 4  2016-W45               Desktop            Desktop         APAC
#
#   Country Name Booking Window Group Property Country  \
# 0  South Korea            8-14 days          Algeria
# 1  South Korea             +90 days          Andorra
# 2  South Korea           46-60 days          Andorra
# 3    Australia           31-45 days        Argentina
# 4    Australia           15-30 days        Argentina
#
#    Net Gross Booking Value USD  Net Orders   datetime Week No  Year
# 0                    -608.4244          -3 2016-11-07      45  2016
# 1                    -512.1796          -2 2016-11-07      45  2016
# 2                     103.4298           1 2016-11-07      45  2016
# 3                     395.9592           1 2016-11-07      45  2016
# 4                     373.4194           1 2016-11-07      45  2016

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
x = dataset['Week No'].values
y = dataset['Net Orders'].values
type(x)
# Out:
# numpy.ndarray

# %%
# Plot
plt.scatter(dataset['Mobile Indicator Name'].values, dataset['Platform Type Name'].values)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Plot
plt.scatter(dataset['Net Gross Booking Value USD'].values, dataset['Net Orders'].values)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('Net Gross Booking Value USD')
plt.ylabel('Net Orders')
plt.show()

# %%
type(y)
# Out:
# numpy.ndarray

# %%
# Plot
plt.scatter(x, y)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
dataset.groupby('Week').size()
# Out:
# Week
# 2016-W45     8404
# 2016-W46     8536
# 2016-W47     8369
# 2016-W48     8381
# 2017-W45    10156
# 2017-W46    10154
# 2017-W47     9769
# 2017-W48     9919
# dtype: int64

# %%
from speedml import Speedml
sml = Speedml('../input/titanic/train.csv',
              '../input/titanic/test.csv',
              target='Survived', uid='PassengerId')

'/Users/jacobmarlow/Desktop/Assignment_Analytics_Graduate.xlsx',
                    sheet_name='Data'

sml.eda()
